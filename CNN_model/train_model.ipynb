# %%
import CNN_architecture
from Trainer import Trainer
from keras.models import load_model

# %%
# Create a Trainer object with the CNN model
learner = Trainer(CNN_architecture.model)

# Train the model
learner.train_model(
    samples_per_batch=30,  # Number of samples per batch
    total_batches=10,       # Total number of batches to train
    epochs_per_batch=1     # Number of epochs to train per batch
)

# Save the trained model to a file named "CNN.h5"
learner.model.save("CNN.h5")
# Out:
# ...
# 1/1 [==============================] - 0s 31ms/step
# Batch 0:
# Games played: 14
# Mean cells revealed: 48.07142857142857
# Proportion of games won: 0.0
#
# ...
# 1/1 [==============================] - 0s 25ms/step
# Batch 1:
# Games played: 8
# Mean cells revealed: 57.75
# Proportion of games won: 0.0
#
# ...
# 1/1 [==============================] - 0s 25ms/step
# Batch 2:
# Games played: 8
# Mean cells revealed: 70.125
# Proportion of games won: 0.0
#
# ...
# 1/1 [==============================] - 0s 28ms/step
# Batch 3:
# Games played: 9
# Mean cells revealed: 60.888888888888886
# Proportion of games won: 0.0
#
# ...
# 1/1 [==============================] - 0s 25ms/step
# Batch 4:
# Games played: 8
# Mean cells revealed: 45.0
# Proportion of games won: 0.0
#
# ...
# 1/1 [==============================] - 0s 26ms/step
# Batch 5:
# Games played: 9
# Mean cells revealed: 64.66666666666667
# Proportion of games won: 0.0
#
# ...
# 1/1 [==============================] - 0s 25ms/step
# Batch 6:
# Games played: 7
# ...
